# %% [markdown]
# # IMPORTING LIBRARIES :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # IMPORTING DATASET :

# %%
df=pd.read_csv('dataset\iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # CHECKING MISSING VALUES:

# %%
missing_values=df.isnull().sum()
missing_values
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # CHECKING THE DUPLICATION VALUES :

# %%
check_duplicate=df.duplicated().sum()
check_duplicate
# Out:
# 0

# %% [markdown]
# # CHANGING COLUMNS IN LOWERCASE

# %%
changing_column_lowercase=df.columns.str.lower()
changing_column_lowercase
# Out:
# Index(['id', 'sepallengthcm', 'sepalwidthcm', 'petallengthcm', 'petalwidthcm',
#        'species'],
#       dtype='object')

# %% [markdown]
# # CHANGING COLUMNS IN UPPERCASE

# %%
df_columns=df.columns.str.upper()
df_columns
# Out:
# Index(['ID', 'SEPALLENGTHCM', 'SEPALWIDTHCM', 'PETALLENGTHCM', 'PETALWIDTHCM',
#        'SPECIES'],
#       dtype='object')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # FOR CATAGORICAL

# %%
df
plt.figure(figsize=(8,6))
plt.bar(df['Species'],df['SepalWidthCm'],color='skyblue',width=0.3)
# Out:
# <BarContainer object of 150 artists>

# %% [markdown]
# # PIE CHART FOR CATAGORICAL:

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.pie(df['SepalLengthCm'],labels=df['Species'],autopct='%1.1f%%',  startangle=180)
plt.title('Distribution of Sepal Length by Species')
plt.show()

# %%
df
plt.figure(figsize=(8, 8))
plt.pie(df['SepalLengthCm'], labels=df['Species'], autopct='%1.1f%%', startangle=180)
plt.title('Distribution of Sepal Length by Species')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (Ensure your actual DataFrame has similar structure)
data = {'Species': ['Setosa', 'Versicolor', 'Virginica'],
        'SepalLengthCm': [50, 60, 40]
df = pd.DataFrame(data)

# Display the DataFrame
print(df)

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(df['SepalLengthCm'], labels=df['Species'], autopct='%1.1f%%', startangle=180)
plt.title('Distribution of Sepal Length by Species')
plt.show()
# Out:
#       Species  SepalLengthCm
# 0      Setosa             50
# 1  Versicolor             60
# 2   Virginica             40

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # COUNT PLOT :

# %%
 
    sns.countplot(x='Species', data=df)
    plt.title('count of each Species')
    plt.xlabel('Species')
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# # FOR NUMERICAL :  HISTOGRAM

# %%
df
plt.hist(df['SepalLengthCm'],color="pink",bins=10,edgecolor="yellow",width=2.5)
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # CATAGORICAL VS NUMERICAL : BOX PLOT

# %%
sns.boxplot(x='Species', y='SepalLengthCm', data=df, palette='pastel') 
plt.title('Customized Box Plot of Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.grid(True) # Adds grid lines plt.show()
